# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcosSilva2021/PythonColab/blob/main/int_pandas_train_p4_Filtros_GroupBy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importando

# %%
import numpy as np
import pandas as pd
from IPython.display import display, HTML

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# # Aplicando Filtros

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# Visualizando antes dos filtros

# %%
count = df.isna().sum()
count[count > 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# - contanto os valores na coluna SaleCondition

# %%
ct = df['SaleCondition'].value_counts()
ct
# Out:
# SaleCondition
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: count, dtype: int64

# %%
ct > 100
# Out:
# SaleCondition
# Normal      True
# Partial     True
# Abnorml     True
# Family     False
# Alloca     False
# AdjLand    False
# Name: count, dtype: bool

# %%
ct[ct > 100]
# Out:
# SaleCondition
# Normal     1198
# Partial     125
# Abnorml     101
# Name: count, dtype: int64

# %%
df.SaleCondition.value_counts()
# Out:
# SaleCondition
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: count, dtype: int64

# %% [markdown]
# - Esse trecho de código em Pandas está usando a função fillna() para preencher valores ausentes (NaN) na coluna LotFrontage
# ----------------------
# - df['LotFrontage']: Isso seleciona a coluna LotFrontage do DataFrame.
#
# - np.mean(df['LotFrontage']): Aqui, a média dos valores da coluna LotFrontage é calculada usando a função mean() do NumPy. Essa média é utilizada para substituir os valores ausentes.
#
# - fillna(...): O método fillna() é utilizado para substituir valores NaN por um valor especificado — nesse caso, a média calculada.
#
# - inplace=True: Isso significa que a operação é realizada diretamente no DataFrame df, sem a necessidade de criar uma nova cópia. O DataFrame original é modificado.

# %%
df['LotFrontage'].fillna(np.mean(df['LotFrontage']), inplace=True)
# Out:
# <ipython-input-12-992ea1d39abe>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LotFrontage'].fillna(np.mean(df['LotFrontage']), inplace=True)

# %%
df['LotFrontage'].fillna(np.mean(df['LotFrontage']), inplace=False)
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
count = df.isna().sum()
count[count > 0]
# Out:
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# # Deletar colunas

# %%
df.drop(columns=['Alley', 'MasVnrType'], inplace=True)

# %%
del(df['Fence'])

# %% [markdown]
# # Groupby()

# %% [markdown]
# - Agrupa os dados por uma ou mais colunas e aplica uma função de agregação a cada grupo.

# %% [markdown]
# Análise do Código
#
#    - df.groupby('SaleCondition'): Isso agrupa o DataFrame df com base nas diferentes categorias encontradas na coluna SaleCondition. Cada grupo corresponderá a um valor único dessa coluna.
#
#    - [['SalePrice', 'LotFrontage']]: Aqui, você está selecionando duas colunas, SalePrice e LotFrontage, para calcular suas médias dentro de cada grupo.
#
#   - mean(): Este método calcula a média dos valores para as colunas selecionadas (SalePrice e LotFrontage) dentro de cada grupo formado anteriormente.
#
#   - O resultado será um novo DataFrame que contém as médias, indexado pelos valores únicos de SaleCondition.

# %%
df.groupby('SaleCondition')[['SalePrice', 'LotFrontage']].mean()
# Out:
#                    SalePrice  LotFrontage
# SaleCondition
# Abnorml        146526.623762    68.285637
# AdjLand        104125.000000    54.500000
# Alloca         167377.416667    65.674993
# Family         149600.000000    73.004996
# Normal         175202.219533    69.307880
# Partial        272291.752000    79.032400

# %% [markdown]
# Esse trecho de código utiliza o método groupby() do Pandas em conjunto com agg() para calcular várias estatísticas do DataFrame, agrupado pela coluna SaleCondition.

# %% [markdown]
# - df.groupby('SaleCondition'): Agrupa o DataFrame df com base nos valores únicos da coluna SaleCondition.
#
# - .agg({...}): O método agg() permite aplicar diferentes funções de agregação a diferentes colunas do DataFrame. No dicionário que você passa como argumento, cada chave corresponde a uma coluna do DataFrame, e o valor associado a essa chave é a função de agregação que você deseja aplicar.
#
#    -  "SalePrice": np.mean: Para a coluna SalePrice, você está calculando a média dos preços de venda para cada grupo de SaleCondition.
#
#    - "LotFrontage": "max": Para a coluna LotFrontage, você está obtendo o valor máximo da frente do lote para cada grupo.
#
#    - "SaleType": np.unique: Para a coluna SaleType, você está utilizando np.unique, que retorna os valores únicos dessa coluna para cada grupo. Isso pode ser útil para entender quais tipos de venda estão presentes em cada condição de venda.

# %%
df.groupby('SaleCondition').agg({"SalePrice": np.mean, "LotFrontage": "max", "SaleType": np.unique})
# Out:
# <ipython-input-22-14b4cc4b59a2>:1: FutureWarning: The provided callable <function mean at 0x789c88b3c1f0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby('SaleCondition').agg({"SalePrice": np.mean, "LotFrontage": "max", "SaleType": np.unique})
#                    SalePrice  LotFrontage  \
# SaleCondition
# Abnorml        146526.623762        174.0
# AdjLand        104125.000000         65.0
# Alloca         167377.416667         78.0
# Family         149600.000000        182.0
# Normal         175202.219533        313.0
# Partial        272291.752000        313.0
#
#                                                SaleType
# SaleCondition
# Abnorml               [COD, CWD, ConLD, ConLI, Oth, WD]
# AdjLand                                            [WD]
# Alloca                                             [WD]
# ...

# %% [markdown]
# - df.loc -- Faz 0 filtro de dados baseado nas colunas

# %%
df_normal = df.loc[df.SaleCondition == 'Normal']

# %%
df_normal.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
# 5   6          50       RL         85.0    14115   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... ScreenPorch PoolArea PoolQC MiscFeature MiscVal  \
# 0    AllPub    Inside  ...           0        0    NaN         NaN       0
# 1    AllPub       FR2  ...           0        0    NaN         NaN       0
# 2    AllPub    Inside  ...           0        0    NaN         NaN       0
# 4    AllPub       FR2  ...           0        0    NaN         NaN       0
# 5    AllPub    Inside  ...           0        0    NaN        Shed     700
#
# ...

# %%
df_normal['SaleCondition'].value_counts()
# Out:
# SaleCondition
# Normal    1198
# Name: count, dtype: int64
