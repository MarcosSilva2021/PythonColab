# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcosSilva2021/PythonColab/blob/main/Np2_Exercicio_Prof.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Respostas exer 2

# %% [markdown]
# anotações : https://colab.research.google.com/drive/1dfMlKQrHVi9ialw3AWfhig_A8z1qRA1U#scrollTo=L4yQdiJDWAEv

# %%
import numpy as np
import pandas as pd

# %%
vendas = pd.read_csv("/content/Vendas - 2017.csv", encoding="latin", sep=";")
produtos = pd.read_csv("/content/Produtos.csv", encoding="latin", sep=";")
clientes = pd.read_csv("/content/Clientes.csv", encoding="latin", sep=";")

# %% [markdown]
# - exibindo as tabelas

# %%
vendas.head()
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1                2    01/01/2017    06/01/2017         5      308        1586
# 2                3    01/01/2017    01/01/2017         0      294        1444
# 3                4    01/01/2017    01/01/2017         0      251        1468
# 4                5    01/01/2017    07/01/2017         6       94        1106
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida
# 0          2.0      6825.0                 9.0                   1.0
# 1          2.0     18469.0                 9.0                   1.0
# 2          5.0     19730.0                13.0                   1.0
# 3          5.0     29326.0                 6.0                   1.0
# 4          2.0     22617.0                 4.0                   1.0

# %%
produtos.head(3)
# Out:
#                                  ÿNome do Produto  \
# 0           Contoso Wireless Laser Mouse E50 Grey
# 1   Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2  Contoso Optical Wheel OEM PS/2 Mouse E60 Black
#
#                                 Descricao do Produto    Fabricante  \
# 0  Advanced 2.4 GHz cordless technology makes fre...  Contoso, Ltd
# 1                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 2                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
#
#   Nome da Marca       Tipo Custo Unitario Preco Unitario  ID Produto  \
# 0       Contoso  Econômico          10,69          20,96         873
# 1       Contoso  Econômico           6,63             13         879
# 2       Contoso  Econômico           6,63             13         880
#
#    ID Subcategoria
# 0               22
# 1               22
# 2               22

# %%
clientes.head(3)
# Out:
#    ÿID Cliente Primeiro Nome   Sobrenome                       E-mail  \
# 0            1        Garnet  Lanfranchi  glanfranchi0@mayoclinic.com
# 1            2       Lurette   Roseblade    lroseblade1@bigcartel.com
# 2            3       Glenden   Ishchenko    gishchenko2@moonfruit.com
#
#       Genero  Numero de Filhos Data de Nascimento  Unnamed: 7  Unnamed: 8  \
# 0   Feminino                 2         12/05/1995         NaN         NaN
# 1   Feminino                 2         30/06/1943         NaN         NaN
# 2  Masculino                 5         09/04/1989         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN

# %% [markdown]
#  # analises
#
# Qual cliente comprou mais em valor?
# Qual o produto mais vendido?
# Qual produto foi mais devolvido?
# Agrupe os produtos por marca e some a quantidade vendida

# %% [markdown]
# - Qual cliente comprou mais em valor?
# - Qual o produto mais vendido?
# - Qual produto foi mais devolvido?
# - Agrupe os produtos por marca e some a quantidade vendida

# %% [markdown]
# # Qual o produto mais vendido

# %%
vendas.groupby("ID Produto").agg({"Quantidade Vendida": "sum"}).sort_values("Quantidade Vendida", ascending=False)
# Out:
#             Quantidade Vendida
# ID Produto
# 2492                    114300
# 2488                    113880
# 2490                    113440
# 2517                    113400
# 2489                    113060
# ...                        ...
# 34                         136
# 171                        124
# 36                         110
# 35                          94
# 184                         86
#
# [1244 rows x 1 columns]

# %% [markdown]
# juntar as tab vendas e Produtos

# %%
vendas_produtos = pd.merge(produtos, vendas, on="ID Produto")
vendas_produtos.head()
# Out:
#                                 ÿNome do Produto  \
# 0  Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 1  Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2  Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 3  Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 4  Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
#
#              Descricao do Produto    Fabricante Nome da Marca       Tipo  \
# 0  PS/2 mouse, 6 feet mouse cable  Contoso, Ltd       Contoso  Econômico
# 1  PS/2 mouse, 6 feet mouse cable  Contoso, Ltd       Contoso  Econômico
# 2  PS/2 mouse, 6 feet mouse cable  Contoso, Ltd       Contoso  Econômico
# 3  PS/2 mouse, 6 feet mouse cable  Contoso, Ltd       Contoso  Econômico
# 4  PS/2 mouse, 6 feet mouse cable  Contoso, Ltd       Contoso  Econômico
#
#   Custo Unitario Preco Unitario  ID Produto  ID Subcategoria  Numero da Venda  \
# 0           6,63             13         879               22              119
# 1           6,63             13         879               22              293
# 2           6,63             13         879               22             1928
# 3           6,63             13         879               22             3333
# 4           6,63             13         879               22             4688
#
#   Data da Venda Data do Envio  ID Canal  ID Loja  ID Promocao  ID Cliente  \
# 0    01/01/2017    01/01/2017         0      149          2.0     17163.0
# 1    01/01/2017    01/01/2017         0       47          2.0     22093.0
# 2    01/01/2017    01/01/2017         0      309         10.0     12571.0
# 3    02/01/2017    03/01/2017         1       51          2.0     33738.0
# 4    02/01/2017    03/01/2017         1      306         10.0     17933.0
#
#    Quantidade Vendida  Quantidade Devolvida
# 0                 4.0                   0.0
# 1                 4.0                   1.0
# 2                 8.0                   0.0
# 3                 4.0                   0.0
# 4                 4.0                   0.0

# %% [markdown]
# # qual cliente comprou mais (qdade)

# %%
vendas['ID Cliente'].value_counts()
# Out:
# ID Cliente
# 19266.0    23
# 29941.0    22
# 24657.0    21
# 19930.0    21
# 24277.0    21
#            ..
# 848.0       1
# 1300.0      1
# 35361.0     1
# 33794.0     1
# 39178.0     1
# Name: count, Length: 37363, dtype: int64

# %% [markdown]
# # Qual cliente comprou mais (valor)

# %%
vendas_produtos["total vendas"] = vendas_produtos['Preco Unitario'] * vendas_produtos['Quantidade Vendida']

# %%
vendas_produtos.groupby("ID Cliente").agg({"total vendas": "sum"}).sort_values("total vendas", ascending=False )
# Out:
#             total vendas
# ID Cliente
# 15624.0        189628.00
# 14312.0        173586.00
# 11421.0        166253.90
# 18549.0        162409.55
# 26943.0        161946.30
# ...                  ...
# 1229.0             38.00
# 37012.0            38.00
# 35075.0            34.75
# 39478.0            34.75
# 38825.0            27.80
#
# [37363 rows x 1 columns]

# %% [markdown]
# # outro modo de calcular qual  cliente fez mais compras'

# %%
resultado = vendas_produtos.groupby("ID Cliente").agg(total_vendas=lambda x: (x['Preco Unitario'] * x['Quantidade Vendida']).sum()).sort_values("total_vendas", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-21695493f854> in <cell line: 1>()
# ----> 1 resultado = vendas_produtos.groupby("ID Cliente").agg(total_vendas=lambda x: (x['Preco Unitario'] * x['Quantidade Vendida']).sum()).sort_values("total_vendas", ascending=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1420     @doc(_agg_template_frame, examples=_agg_examples_doc, klass="DataFrame")
#    1421     def aggregate(self, func=None, *args, engine=None, engine_kwargs=None, **kwargs):
# -> 1422         relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    1423         func = maybe_mangle_lambdas(func)
#    1424
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in reconstruct_func(func, **kwargs)
#    1694         if func is None:
#    1695             # nicer error message
# -> 1696             raise TypeError("Must provide 'func' or tuples of '(column, aggfunc).")
#    1697
#    1698     if relabeling:
#
# TypeError: Must provide 'func' or tuples of '(column, aggfunc).

# %% [markdown]
# # agrupar produtos por marca e somar a qdade vendida

# %%
vendas_produtos.groupby("Nome da Marca").agg({"Quantidade Vendida": "sum"}).sort_values("Quantidade Vendida", ascending=False)
# Out:
#                       Quantidade Vendida
# Nome da Marca
# Contoso                          4853792
# Proseware                        1173515
# Fabrikam                         1110570
# The Phone Company                1064954
# A. Datum                         1035036
# Southridge Video                  951703
# Adventure Works                   817579
# Wide World Importers              633311
# Litware                           148132
# Northwind Traders                  63336

# %% [markdown]
# # tratando os dados object -> float

# %%
vendas_produtos["Preco Unitario"] = vendas_produtos["Preco Unitario"].str.replace(",",".")

# %%
vendas_produtos["Custo Unitario"] = vendas_produtos["Custo Unitario"].str.replace(",",".")

# %% [markdown]
# converter para float

# %%
vendas_produtos["Preco Unitario"] = vendas_produtos["Preco Unitario"].astype(float)

# %%
vendas_produtos["Custo Unitario"] = vendas_produtos["Custo Unitario"].astype(float)

# %% [markdown]
# Faça uma agregação dos dados Pela a coluna Tipo, trazendo a média do preço unitário e a soma da coluna quantidade devolvida

# %%
grup_tipo = vendas_produtos.groupby("Tipo").agg({"Preco Unitario": "mean", "Quantidade Devolvida": "sum"})

# %%
grup_tipo
# Out:
#            Preco Unitario  Quantidade Devolvida
# Tipo
# Econômico      110.244554                 53175
# Luxo           583.578379                 15538
# Regular        326.037983                 70218

# %% [markdown]
# # Crie um gráfico de barras no dataframe grupo_tipo na coluna preço unitário,

# %%
grup_tipo['Preco Unitario'].plot(kind="bar")
# Out:
# <Axes: xlabel='Tipo'>

# %% [markdown]
# # Criação de coluna que é a divisão da coluna quantidade devolvida / quantidade vendida * 100

# %%
vendas_produtos["coef_dev"] = vendas_produtos['Quantidade Devolvida']/ vendas_produtos['Quantidade Vendida'] * 100

# %%
vendas_produtos[["coef_dev"]]
# Out:
#          coef_dev
# 0       16.666667
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# ...           ...
# 980637   0.000000
# 980638   0.000000
# 980639   7.692308
# 980640   0.000000
# 980641   0.000000
#
# [980642 rows x 1 columns]
